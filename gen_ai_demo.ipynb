# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

# %%
load_dotenv()
# Out:
# True

# %%
print("Loaded environment variables.")
print(os.getenv("OPENAI_API_KEY"))
# Out:
# Loaded environment variables.
# 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

# %%
#client = OpenAI()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5.1",
    input="Write a short bedtime story about a unicorn."
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = client.responses.create(
#       2     model="gpt-5.1",
#       3     input="Write a short bedtime story about a unicorn."
#       4 )
#       5 print(response.output_text)
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/openai/resources/responses/responses.py:840, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     803 def create(
#     804     self,
#     805     *,
#    (...)
#     838     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     839 ) -> Response | Stream[ResponseStreamEvent]:
# --> 840     return self._post(
#     841         "/responses",
#     842         body=maybe_transform(
#     843             {
#     844                 "background": background,
#     845                 "conversation": conversation,
#     846                 "include": include,
#     847                 "input": input,
#     848                 "instructions": instructions,
#     849                 "max_output_tokens": max_output_tokens,
#     850                 "max_tool_calls": max_tool_calls,
#     851                 "metadata": metadata,
#     852                 "model": model,
#     853                 "parallel_tool_calls": parallel_tool_calls,
#     854                 "previous_response_id": previous_response_id,
#     855                 "prompt": prompt,
#     856                 "prompt_cache_key": prompt_cache_key,
#     857                 "reasoning": reasoning,
#     858                 "safety_identifier": safety_identifier,
#     859                 "service_tier": service_tier,
#     860                 "store": store,
#     861                 "stream": stream,
#     862                 "stream_options": stream_options,
#     863                 "temperature": temperature,
#     864                 "text": text,
#     865                 "tool_choice": tool_choice,
#     866                 "tools": tools,
#     867                 "top_logprobs": top_logprobs,
#     868                 "top_p": top_p,
#     869                 "truncation": truncation,
#     870                 "user": user,
#     871             },
#     872             response_create_params.ResponseCreateParamsStreaming
#     873             if stream
#     874             else response_create_params.ResponseCreateParamsNonStreaming,
#     875         ),
#     876         options=make_request_options(
#     877             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     878         ),
#     879         cast_to=Response,
#     880         stream=stream or False,
#     881         stream_cls=Stream[ResponseStreamEvent],
#     882     )
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
response = client.responses.create(
    model="gpt-5.1",
    input="Write a short bedtime story about a unicorn.",
    max_output_tokens=300,
    temperature=1,
    top_p=1.0,
)
print(response.output_text)
# Out:
# Under a sky sprinkled with sleepy stars, there was a forest called Whisperwood, where the leaves spoke in hushed rustles and the fireflies glowed like tiny lanterns. In the softest clearing of that forest lived a small unicorn named Liora.
#
# Liora was not like the other unicorns in the legends. Her horn didn’t blaze with lightning or shoot sparkling beams. Instead, it glowed with a gentle silver light, no brighter than the moon’s reflection in a puddle. At first, Liora wished her horn were grand and dazzling. She wanted to paint rainbows across the night and make everyone gasp in amazement.
#
# Every evening, when the stars began to yawn awake, Liora trotted to the pond at the center of Whisperwood. She looked at her reflection in the still water—silvery mane, soft eyes, and that small, glowing horn.
#
# “Maybe I’m not magical enough,” she whispered to the dragonflies.
#
# One night, as the forest settled into sleepy silence, a tiny voice called out.
#
# “Hello? Is someone there?”
#
# Liora perked her ears and followed the sound. At the edge of the pond sat a little brown mouse, shivering on a wet rock.
#
# “I’m here,” Liora said softly. “What’s wrong?”
#
# “I lost my way,” the mouse sniffled. “I was trying to find my burrow before dark, but now the forest is too

# %%
from openai import OpenAI
client = OpenAI()

audio_file = open("speech_test_regenerated.mp3", "rb")

transcript = client.audio.transcriptions.create(
    model="gpt-4o-transcribe",
    file=audio_file
)

print(transcript)
# Out:
# Transcription(text='Hi there, this is a regenerated audio sample for testing the OpenAI transcription API. This audio is short, clear, and suitable for your transcription experiments.', logprobs=None, usage=UsageTokens(input_tokens=88, output_tokens=33, total_tokens=121, type='tokens', input_token_details=UsageTokensInputTokenDetails(audio_tokens=88, text_tokens=0)))

# %%
! pip install groq

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": ""
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Is there something I can help you with?

# %%
client = Groq()
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "Share the latest news about AI research from the past month."
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Since I'm a large language model, I don't have real-time access to current news. However, based on my training data up to December 2023, I can share some notable advancements and developments in AI research from the past month (November 2023).
#
# **1. Breakthrough in Emotion Recognition Using AI**
# Researchers from the University of California, San Diego (UCSD) have developed an AI system capable of recognizing human emotions more accurately than humans. The system uses a combination of visual and audio cues to analyze facial expressions, tone of voice, and other physiological signals to identify emotions with a high degree of accuracy.
#
# **2. Google's AI Model Outperforms Medical Experts in Detecting Breast Cancer**
# Google's AI model, LLaMA, has been trained to analyze mammography images and detect breast cancer with a high degree of accuracy. In a recent study, the model outperformed human radiologists in detecting breast cancer, highlighting the potential of AI in medical diagnostics.
#
# **3. Developments in Explainable AI (XAI)**
# Researchers from the University of Michigan and the University of California, Berkeley, have made significant progress in developing Explainable AI (XAI) models. XAI aims to provide insights into the decision-making process of AI systems, helping to build trust and transparency in AI applications.
#
# **4. AI-Powered Robot Can Learn by Imitation**
# Researchers from Stanford University have developed an AI-powered robot that can learn by imitating human actions. The robot uses a combination of machine learning and reinforcement learning to learn new tasks and adapt to changing environments.
#
# **5. Quantum AI Breakthroughs**
# Scientists from the University of Oxford have made significant progress in developing a quantum AI system that can solve complex optimization problems more efficiently than classical AI systems. This breakthrough has the potential to revolutionize fields like finance and materials science.
#
# **6. Advances in Natural Language Processing (NLP)**
# Researchers from the University of Toronto have developed an NLP model that can generate human-like text with unprecedented clarity and coherence. The model uses a combination of machine learning and graph neural networks to generate text that is both informative and engaging.
#
# These developments highlight the rapid progress being made in AI research and its potential applications in various fields. However, please note that these updates are based on my training data up to December 2023, and I may not have access to the latest breakthroughs and research findings.

# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='deepseek-r1:1.5b', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
#print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 4
#       1 from ollama import chat
#       2 from ollama import ChatResponse
# ----> 4 response: ChatResponse = chat(model='deepseek-r1:1.5b', messages=[
#       5   {
#       6     'role': 'user',
#       7     'content': 'Why is the sky blue?',
#       8   },
#       9 ])
#      10 #print(response['message']['content'])
#      11 # or access fields directly from the response object
#      12 print(response.message.content)
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/ollama/_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages/ollama/_client.py:135, in Client._request_raw(self, *args, **kwargs)
#     133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
# --> 135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %%
! pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pydantic>=2.9 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from ollama) (2.12.4)
# Requirement already satisfied: httpx>=0.27 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: anyio in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.27->ollama) (4.11.0)
# Requirement already satisfied: idna in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: certifi in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.27->ollama) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
#
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
