# %%
import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import langchain
# ----> 2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       3 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#       4 from langchain.vectorstores import Chroma
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
! pip install langchain
# Out:
# Requirement already satisfied: langchain in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.49)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.10)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests>=2.0.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: httpcore==1.* in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: certifi in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: anyio in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: h11>=0.16 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/mahesh/vs_code/agent_ai_iitm/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
#
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
